# %%
import pandas
import theUtility
import os
import webbrowser

print(f"Process's script called from {theUtility.cwd()}")
if os.path.exists(os.path.join(".","Python")): theUtility.cd(os.path.join(".","Python"))
print(f"Process's script working directory -> {theUtility.cwd()}")

user: str = input("Enter user name (Bew / Ote ?): ")

topic_file = "../BusinessCatagoryList.csv"
df_topic = pandas.read_csv(topic_file, dtype=str, encoding="utf-8")

if (len(user) < 1) or (theUtility.getConfig(user.lower()[0]) is None): print("Error: user is not found."); exit(1)
print(f"Hello, {user}.")
user = user.lower()[0]
working_scope = theUtility.getConfig(user)["scope"]
print(f"your working scope is {working_scope}")

def indexClosestToValue(mainList: list[int], value: int):
    return mainList.index(min(mainList, key= lambda x: abs(int(x) - int(value))))

def mapScopeSlicer(mainList: list, scope: tuple):
    firstIndex = indexClosestToValue(mainList, scope[0])
    lastIndex = indexClosestToValue(mainList, scope[1])
    return (firstIndex, lastIndex)

first_index, last_index = mapScopeSlicer([int(i) for i in df_topic["รหัส"].tolist()], working_scope)
df_topic = df_topic[first_index: last_index]
# print(df_topic)

scraped_files = theUtility.listDirTree(os.path.join("..", "Target"))
scraped_files = [(i.split(os.sep)[-1]).split(".")[0] for i in scraped_files]
# print(scraped_files)

available_scope = [i for i in df_topic["รหัส"].tolist() if i in scraped_files]

if len(available_scope) < 1: print("Error: no available scope. If something is wrong, please contact the developer."); exit(1)

print(f"available scope (scraped files): {available_scope[0]} - {available_scope[-1]}")

last_processed_catagory = available_scope[indexClosestToValue(available_scope, theUtility.getConfig(user)["lastProcess"]["catagoryID"])]
print(f"last processed catagory: {last_processed_catagory}")

stacking_result = os.path.join("..", "Result", f"result_{user}.csv")
if os.path.exists(stacking_result): stacking_result = pandas.read_csv(stacking_result, encoding="utf-8", dtype=str).fillna('')
else: stacking_result = pandas.DataFrame()

catagory_id = ""

print(f"appending data to result_{user}.csv from {last_processed_catagory} to {available_scope[-1]}")
for index, row in df_topic[(df_topic["รหัส"].tolist().index(last_processed_catagory) + [0,1][theUtility.getConfig(user)["lastProcess"]["catagoryID"] != "0"]): (df_topic["รหัส"].tolist().index(available_scope[-1]))].iterrows():
    catagory_id = row["รหัส"]
    catagory_name = row["ประเภทธุรกิจ"]
    print(f"Processing catagory -> {catagory_id}: {catagory_name}")

    processing_file = os.path.join("..", "Target", f"{catagory_id}.json")
    if not os.path.exists(processing_file): print(f"Error: {processing_file} is not found."); continue

    try: 
        df_converter = pandas.read_json(processing_file, encoding="utf-8", dtype=str)
        df_converter.to_csv(os.path.join("Temp", f"temp.csv"), index=False, encoding="utf-8")
        df_converter = pandas.read_csv(os.path.join("Temp", f"temp.csv"), encoding="utf-8", dtype=str).fillna('')
        df_converter['เลขทะเบียน'] = df_converter['เลขทะเบียน'].apply(lambda x: "'" + x if not x.startswith("'") else x)
        stacking_result = pandas.concat(objs=[stacking_result, df_converter], ignore_index=True)

        stacking_result = stacking_result.drop_duplicates(subset='เลขทะเบียน').fillna('')

        theUtility.updateConfig((user, "lastProcess", "catagoryID"), catagory_id)
    except Exception as e:
        print(f"Error: cannot process {processing_file}")
        print(e)

print("merged data and starting filtering")

stacking_result['เบอร์โทร'] = ""

stacking_result['ทุนจดทะเบียน'] = stacking_result['ทุนจดทะเบียน'].str.replace(',', '')
stacking_result['ทุนจดทะเบียน'] = stacking_result['ทุนจดทะเบียน'].str.replace(' บาท', '')
stacking_result['ทุนจดทะเบียน'] = pandas.to_numeric(stacking_result['ทุนจดทะเบียน'])
stacking_result = stacking_result[(stacking_result['ทุนจดทะเบียน'] >= 30000000)]
stacking_result['ทุนจดทะเบียน'] = stacking_result['ทุนจดทะเบียน'].astype(str)

stacking_result = stacking_result[stacking_result['สถานะ']=='ยังดำเนินกิจการอยู่']

stacking_result['เลขทะเบียน'] = stacking_result['เลขทะเบียน'].apply(lambda x: "'" + x if not x.startswith("'") else x)

stacking_result['วันที่จดทะเบียน(ชื่อเดือน)'] = stacking_result['วันที่จดทะเบียน']
month_dict = {
    ' มกราคม ': '/1/',
    ' กุมภาพันธ์ ': '/2/',
    ' มีนาคม ': '/3/',
    ' เมษายน ': '/4/',
    ' พฤษภาคม ': '/5/',
    ' มิถุนายน ': '/6/',
    ' กรกฎาคม ': '/7/',
    ' สิงหาคม ': '/8/',
    ' กันยายน ': '/9/',
    ' ตุลาคม ': '/10/',
    ' พฤศจิกายน ': '/11/',
    ' ธันวาคม ': '/12/'
}
for key, value in month_dict.items(): stacking_result['วันที่จดทะเบียน'] = stacking_result['วันที่จดทะเบียน'].str.replace(key, value)

stacking_result["ข้อมูลสำหรับการติดต่อ"] = stacking_result["ข้อมูลสำหรับติดต่อ"].str.startswith("ส")


stacking_result = stacking_result.reset_index(drop=True)
colunm_order = [
    "เลขทะเบียน","ชื่อบริษัทภาษาไทย","ชื่อบริษัทภาษาอังกฤษ","ประกอบธุรกิจ","หมวดธุรกิจ","ที่ตั้ง","สถานะ","วันที่จดทะเบียน","วันที่จดทะเบียน(ชื่อเดือน)","ทุนจดทะเบียน","ก่อตั้งโดย","ข้อมูลสำหรับติดต่อ","ข้อมูลสำหรับการติดต่อ","เบอร์โทร","Website","หลักทรัพย์","ที่มา",
]
stacking_result = stacking_result[colunm_order + [i for i in stacking_result.columns if i not in colunm_order]]
stacking_result.to_csv(os.path.join("..", "Result", f"result_{user}.csv"), index=False, encoding="utf-8")
catagory_id = catagory_id if catagory_id != "" else available_scope[-1]
theUtility.updateConfig((user, "lastProcess", "catagoryID"), catagory_id)

print(f"updated result_{user}.csv from {last_processed_catagory} to {catagory_id} with filtering and cleaning")
print("Press enter to continue... (filling in the missing data process or q to quit)")
if input("Press enter to continue... (q to quit)") == "q": exit(0)

# stacking_result

print("initializing the filling in process, loading the data...")
df_filling_in = pandas.read_csv(os.path.join("..", "Result", f"result_{user}.csv"), encoding="utf-8", dtype=str).fillna('')

last_cpmpany_id = theUtility.getConfig(user)["lastProcess"]["companyID"]
last_cpmpany_index = df_filling_in["เลขทะเบียน"].tolist().index(last_cpmpany_id) if last_cpmpany_id != "0" else 0
last_cpmpany_index = int(theUtility.getConfig(user)["lastProcess"]["index"])

company_id = ""
last_index = 0

for index, row in df_filling_in[last_cpmpany_index + 1:].iterrows():
    last_index = int(index)
    company_id = row["เลขทะเบียน"]
    company_name = row["ชื่อบริษัทภาษาไทย"]
    company_name_eng = row["ชื่อบริษัทภาษาอังกฤษ"]
    print("=" * 20)
    print(f"[{index}] Company {company_id} -> {company_name} | {company_name_eng}")

    phone_number = row["เบอร์โทร"]
    website = row["Website"]
    website_a = row["เว็บไซต์"]
    address = row["ที่ตั้ง"]
    source = row["ที่มา"]

    print(f"phone_number: {phone_number} \nwebsite: {website} {website_a} \naddress: {address} \nsource: {source}")

    if (phone_number != "") and (website != "" or website_a != "") and (address != "") and (source != ""): 
        print(f"This one has all the information, skipping...")
        print(row)
        continue
    else:
        if phone_number == "":
            print("please fill in the phone number")
            url = f"https://www.google.com/search?q={company_name.replace(' ', '+')}+ติดต่อ"
            if row["ข้อมูลสำหรับการติดต่อ"].startswith("t"):
                print("The record shows that there is phone number from the source, so try this...")
                print(source)
                # webbrowser.open(source)
            else: pass # webbrowser.open(url)
            print(url)
            phone_number = input("Enter phone number (b to stop): ")
            if phone_number.startswith("b"):
                print("stop filling in")
                break
            # if phone_number.startswith("s"):
            #     print("skip phone number")
            #     phone_number = ""
            # elif phone_number == "":
            #     url = f"https://www.google.com/search?q={company_name_eng.replace(' ', '+')}+contact"
            #     print(url)
            #     # webbrowser.open(url)
            #     phone_number = input("Enter phone number: ")
            phone_number = phone_number.replace(" ", "").strip()
            df_filling_in.at[index, "เบอร์โทร"] = "'" + phone_number if phone_number != "" else ""
        if website == "":
            if website_a != "": website = website_a
            else:
                print("please fillin the website")
                url = f"https://www.google.com/search?q={company_name.replace(' ', '+')}"
                print(url)
                # webbrowser.open(url)
                website = input("Enter website (b to stop): ")
                if website.startswith("b"):
                    print("stop filling in")
                    break
                # if website.startswith("s"):
                #     print("skip website")
                #     website = ""
                # elif website == "":
                #     url = f"https://www.google.com/search?q={company_name_eng.replace(' ', '+')}"
                #     print(url)
                #     # webbrowser.open(url)
                #     website = input("Enter website: ")
                website = website.replace(" ", "").strip()
                df_filling_in.at[index, "Website"] = website
        if address == "":
            print("please fillin the address")
            url = f"https://www.google.com/search?q={company_name.replace(' ', '+')}+ที่ตั้ง"
            print(url)
            # webbrowser.opeurl=n(url)
            address = input("Enter address (b to stop): ")
            if address.startswith("b"):
                print("stop filling in")
                break
            # if address.startswith("s"):
            #     print("skip address")
            #     address = ""
            # elif address == "":
            #     url = f"https://www.google.com/search?q={company_name_eng.replace(' ', '+')}+location"
            #     print(url)
            #     # webbrowser.open(url)
            #     address = input("Enter address: ")
            address = address.replace(" ", "").strip()
            df_filling_in.at[index, "ที่ตั้ง"] = address
    
    print("Data have been filled in. Drafted to data frame.")

theUtility.updateConfig((user, "lastProcess", "companyID"), company_id)
theUtility.updateConfig((user, "lastProcess", "index"), last_index)

df_filling_in.to_csv(os.path.join("..", "Result", f"result_{user}.csv"), index=False, encoding="utf-8")
# Out:
# Process's script called from d:\Projects\QuickERP\Work2 - DataForThai\WebScrapperFor_DataForThai\Python
# Process's script working directory -> d:\Projects\QuickERP\Work2 - DataForThai\WebScrapperFor_DataForThai\Python
# Hello, b.
# your working scope is [0, 46100]
# theUtility[listDirTree]: Listing directory tree for ..\Target
# available scope (scraped files): 01111 - 07299
# last processed catagory: 01111
# appending data to result_b.csv from 01111 to 07299
# Processing catagory -> 01111: การปลูกข้าวโพดที่ใช้เมล็ดแก่
# Processing catagory -> 01112: การปลูกธัญพืช (ยกเว้นข้าวและข้าวโพด)
# Processing catagory -> 01113: การปลูกพืชตระกูลถั่ว
# Processing catagory -> 01114: การปลูกถั่วเหลือง
# Error: ..\Target\01114.json is not found.
# Processing catagory -> 01115: การปลูกพืชน้ำมัน (ยกเว้นถั่วเหลือง)
# Processing catagory -> 01121: การปลูกข้าวจ้าว
# Processing catagory -> 01122: การปลูกข้าวเหนียว
# Error: ..\Target\01122.json is not found.
# Processing catagory -> 01131: การปลูกพืชผักกินใบและพืชผักกินต้น รวมถึงการเพาะเมล็ดพันธุ์ผัก
# Processing catagory -> 01132: การปลูกพืชผักกินผลรวมถึงแตงชนิดต่าง ๆ รวมถึงการเพาะเมล็ดพันธุ์ผัก
# Processing catagory -> 01133: การปลูกพืชผักกินหัว
# Error: ..\Target\01133.json is not found.
# Processing catagory -> 01135: การปลูกมันสำปะหลัง
# Processing catagory -> 01136: การเพาะเห็ด
# Processing catagory -> 01139: การปลูกพืชผักอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01140: การปลูกอ้อย
# Processing catagory -> 01150: การปลูกยาสูบ
# Error: ..\Target\01150.json is not found.
# Processing catagory -> 01161: การปลูกฝ้าย
# Error: ..\Target\01161.json is not found.
# Processing catagory -> 01169: การปลูกพืชเส้นใยอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Error: ..\Target\01169.json is not found.
# Processing catagory -> 01191: การปลูกข้าวโพดเลี้ยงสัตว์
# Processing catagory -> 01192: การปลูกพืชล้มลุกที่ใช้เป็นอาหารสัตว์ (ยกเว้นข้าวโพด เลี้ยงสัตว์)
# Processing catagory -> 01193: การปลูกกล้วยไม้
# Processing catagory -> 01194: การปลูกไม้ดอกอื่นๆ (ยกเว้นกล้วยไม้)
# Processing catagory -> 01199: การปลูกพืชล้มลุกชนิดอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01210: การทำสวนองุ่น
# Processing catagory -> 01221: การปลูกสับปะรด
# Processing catagory -> 01222: การปลูกทุเรียน
# Processing catagory -> 01223: การปลูกลำไย
# Error: ..\Target\01223.json is not found.
# Processing catagory -> 01224: การปลูกมะม่วง
# Error: ..\Target\01224.json is not found.
# Processing catagory -> 01225: การปลูกกล้วย
# Error: ..\Target\01225.json is not found.
# Processing catagory -> 01226: การปลูกมังคุด
# Error: ..\Target\01226.json is not found.
# Processing catagory -> 01227: การปลูกเงาะ
# Error: ..\Target\01227.json is not found.
# Processing catagory -> 01229: การปลูกไม้ผลเมืองร้อนและกึ่งร้อนอื่นๆซึ่งมิได้จัดประเภท ไว้ในที่อื่น
# Processing catagory -> 01231: การปลูกส้ม
# Processing catagory -> 01239: การปลูกไม้ผลตระกูลส้มอื่นๆซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01249: การปลูกไม้ผลเมืองหนาวอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Error: ..\Target\01249.json is not found.
# Processing catagory -> 01251: การปลูกไม้ผลเปลือกแข็งที่กินได้
# Error: ..\Target\01251.json is not found.
# Processing catagory -> 01259: การปลูกไม้ผลยืนต้นอื่นๆซึ่งมิได้จัดประเภทไว้ในทื่อื่น
# Processing catagory -> 01261: การปลูกปาล์มน้ำมัน
# Processing catagory -> 01262: การปลูกมะพร้าว
# Processing catagory -> 01269: การปลูกไม้ยืนต้นอื่นๆที่ให้น้ำมันซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Error: ..\Target\01269.json is not found.
# Processing catagory -> 01271: การทำไร่ชา
# Processing catagory -> 01272: การทำไร่กาแฟ
# Processing catagory -> 01279: การปลูกพืชอื่นๆที่นำไปทำเครื่องดื่มซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01281: การปลูกพริก
# Error: ..\Target\01281.json is not found.
# Processing catagory -> 01282: การปลูกพริกไทย
# Error: ..\Target\01282.json is not found.
# Processing catagory -> 01289: การปลูกพืชอื่นๆประเภทเครื่องเทศเครื่องหอมยารักษาโรค และพืชทางเภสัชภัณฑ์ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01291: การปลูกต้นยางพารา
# Processing catagory -> 01292: การปลูกพืชที่ใช้ในการถักสาน
# Error: ..\Target\01292.json is not found.
# Processing catagory -> 01299: การปลูกพืชยืนต้นประเภทอื่นๆซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01301: การทำสวนไม้ประดับ
# Processing catagory -> 01302: การปลูกพืชการเพาะพันธุ์และการขยายพันธุ์พืชอื่นๆ
# Processing catagory -> 01411: การเลี้ยงโคนมและโคเนื้อ
# Processing catagory -> 01412: การเลี้ยงกระบือนมและกระบือเนื้อ
# Processing catagory -> 01419: การเลี้ยงโคและกระบือเพื่อวัตถุประสงค์อื่นๆซึ่งมิได้จัดประเภท ไว้ในที่อื่น
# Error: ..\Target\01419.json is not found.
# Processing catagory -> 01420: การเลี้ยงม้าลาล่อม้าล่อและสัตว์อื่นๆที่คล้ายม้า
# Error: ..\Target\01420.json is not found.
# Processing catagory -> 01441: การเลี้ยงแกะ
# Error: ..\Target\01441.json is not found.
# Processing catagory -> 01442: การเลี้ยงแพะ
# Error: ..\Target\01442.json is not found.
# Processing catagory -> 01450: การเลี้ยงสุกร
# Processing catagory -> 01461: การเลี้ยงไก่ไข่
# Processing catagory -> 01462: การเลี้ยงไก่เนื้อ
# Processing catagory -> 01463: การเลี้ยงเป็ด
# Processing catagory -> 01469: การเลี้ยงสัตว์ปีกอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01492: การเลี้ยงไหมผีเสื้อและแมลง
# Processing catagory -> 01493: การเลี้ยงผึ้ง
# Error: ..\Target\01493.json is not found.
# Processing catagory -> 01494: การเลี้ยงนกนางแอ่น
# Processing catagory -> 01496: การทำฟาร์มสัตว์เลี้ยง (ยกเว้นสัตว์น้ำ)
# Processing catagory -> 01499: การเลี้ยงสัตว์ประเภทอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01500: การทำฟาร์มผสมผสาน
# Processing catagory -> 01600: กิจกรรมสนับสนุนการเกษตรและกิจกรรมหลังการเก็บเกี่ยว
# Error: ..\Target\01600.json is not found.
# Processing catagory -> 01611: การควบคุมแมลงและสัตว์ศัตรูพืช
# Processing catagory -> 01612: การดำเนินการเกี่ยวกับอุปกรณ์การให้น้ำและเครื่องมือชลประทาน ทางการเกษตร
# Error: ..\Target\01612.json is not found.
# Processing catagory -> 01619: กิจกรรมสนับสนุนการผลิตพืชผลซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01621: กิจกรรมสนับสนุนการแพร่พันธุ์สัตว์
# Processing catagory -> 01629: กิจกรรมสนับสนุนการเลี้ยงสัตว์อื่นๆซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 01630: กิจกรรมหลังการเก็บเกี่ยวพืชผล
# Processing catagory -> 01640: กระบวนการจัดการเมล็ดพันธุ์เพื่อการขยายพันธุ์
# Processing catagory -> 01700: การล่าสัตว์การดักสัตว์และกิจกรรมบริการอื่นๆที่เกี่ยวข้อง
# Error: ..\Target\01700.json is not found.
# Processing catagory -> 02100: วนวัฒนวิทยาและกิจกรรมอื่นๆที่เกี่ยวกับป่าไม้
# Processing catagory -> 02200: การทำไม้
# Processing catagory -> 02300: การเก็บหาของป่า
# Error: ..\Target\02300.json is not found.
# Processing catagory -> 02400: บริการสนับสนุนการป่าไม้
# Processing catagory -> 03111: การจับปลาทะเล
# Processing catagory -> 03112: การจับกุ้งทะเล
# Processing catagory -> 03113: การจับปูทะเล
# Error: ..\Target\03113.json is not found.
# Processing catagory -> 03114: การจับหมึก
# Error: ..\Target\03114.json is not found.
# Processing catagory -> 03115: การจับหอยทะเล
# Error: ..\Target\03115.json is not found.
# Processing catagory -> 03119: การประมงทะเลอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 03121: การจับปลาน้ำจืด
# Error: ..\Target\03121.json is not found.
# Processing catagory -> 03122: การจับกุ้งน้ำจืด
# Error: ..\Target\03122.json is not found.
# Processing catagory -> 03129: การประมงน้ำจืดอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Error: ..\Target\03129.json is not found.
# Processing catagory -> 03211: การเพาะเลี้ยงปลาทะเล
# Processing catagory -> 03212: การเพาะเลี้ยงกุ้งทะเล
# Processing catagory -> 03213: การเพาะเลี้ยงหอยทะเล
# Error: ..\Target\03213.json is not found.
# Processing catagory -> 03214: การเพาะเลี้ยงสัตว์ทะเลสวยงาม
# Error: ..\Target\03214.json is not found.
# Processing catagory -> 03219: การเพาะเลี้ยงสัตว์น้ำทะเลอื่นๆซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 03221: การเพาะเลี้ยงปลาน้ำจืด
# Processing catagory -> 03222: การเพาะเลี้ยงกุ้งน้ำจืด
# Processing catagory -> 03223: การเพาะเลี้ยงกบ
# Error: ..\Target\03223.json is not found.
# Processing catagory -> 03224: การเพาะเลี้ยงจระเข้
# Processing catagory -> 03225: การเพาะเลี้ยงสัตว์น้ำจืดสวยงาม
# Error: ..\Target\03225.json is not found.
# Processing catagory -> 03229: การเพาะเลี้ยงสัตว์น้ำจืดอื่นๆ ซึ่งมิได้จัดประเภทไว้ในที่อื่น
# Processing catagory -> 05100: การทำเหมืองถ่านหินคุณภาพสูง
# Processing catagory -> 05200: การทำเหมืองลิกไนต์
# Processing catagory -> 06100: การผลิตน้ำมันดิบ
# Processing catagory -> 06200: การผลิตก๊าซธรรมชาติ
# Processing catagory -> 07100: การทำเหมืองสินแร่เหล็ก
# Processing catagory -> 07210: การทำเหมืองสินแร่ยูเรเนียมและทอเรียม
# Error: ..\Target\07210.json is not found.
# Processing catagory -> 07291: การทำเหมืองสินแร่ดีบุก
# Processing catagory -> 07292: การทำเหมืองสินแร่สังกะสี
# merged data and starting filtering
# updated result_b.csv from 01111 to 07292 with filtering and cleaning
# Press enter to continue... (filling in the missing data process or q to quit)
# initializing the filling in process, loading the data...
# ====================
# [10] Company '0125563001627 -> บริษัท บีแอลเอชวายสิบสี่ จำกัด | BLHY14 CO., LTD.
# phone_number:
# website:
# address: 91/86 หมู่บ้าน พาทิโอ หมู่ที่ 5 ตำบลบ้านใหม่ อำเภอปากเกร็ด จ.นนทบุรี 11120
# source: https://www.dataforthai.com/company/0125563001627/
# please fill in the phone number
# https://www.google.com/search?q=บริษัท+บีแอลเอชวายสิบสี่+จำกัด+ติดต่อ
# please fillin the website
# https://www.google.com/search?q=บริษัท+บีแอลเอชวายสิบสี่+จำกัด
# Data have been filled in. Drafted to data frame.
# ====================
# [11] Company '0105563099589 -> บริษัท ป่า ดอนพุทรา จำกัด | PA DONPHUTSA CO., LTD.
# phone_number:
# website:
# address: 81/1 ซอยเพชรเกษม 54 แยก 3 แขวงบางด้วน เขตภาษีเจริญ กรุงเทพมหานคร 10160
# source: https://www.dataforthai.com/company/0105563099589/
# please fill in the phone number
# https://www.google.com/search?q=บริษัท+ป่า+ดอนพุทรา+จำกัด+ติดต่อ
# please fillin the website
# https://www.google.com/search?q=บริษัท+ป่า+ดอนพุทรา+จำกัด
# stop filling in
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
